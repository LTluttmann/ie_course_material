# %% [markdown]
# # Week 01 — Exercise: Introduction to Information Extraction
#
# **Learning goals:**
# - Apply basic text preprocessing techniques
# - Differentiate between Information Retrieval (IR) and Information Extraction (IE)
# - Implement simple rule-based extraction tasks
#
# ---

# %%
import spacy
from rich import print as rprint
from ie_course.utils import normalize_whitespace, sentence_tokenize

nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ## 1. Text Preprocessing
#
# In real-world IE, data is often "dirty" (excessive whitespace, inconsistent casing, etc.). The first step is always normalization.
#
# **Task:** Clean the following raw text snippet.

# %%
raw_text = "  Information Extraction    is a subfield of NLP.   \n\nIt focuses on extracting structured information  from unstructured text.  "

# TODO: 
# 1. Use normalize_whitespace to collapse the whitespace
# 2. Convert the text to lowercase
# 3. Split the cleaned text into sentences using sentence_tokenize

cleaned_text = ""
sentences = []

# %%
print(f"Cleaned: {cleaned_text}")
print(f"Sentences: {sentences}")

# %% [markdown]
# ## 2. Simple Extraction Task
#
# Imagine you are processing a batch of short business emails. You need to extract the **Amount** and the **Currency** from the following text.
#
# **Text:** "Please find the attached invoice for the amount of 1,250.00 EUR. Payment is due by next Friday."
#
# **Task:** Implement a simple extraction logic. While you will learn Regular Expressions (Regex) in the next exercise, try to solve this using basic Python string methods (e.g., `.find()`, `.split()`, `.strip()`, etc.).

# %%
email_text = "Please find the attached invoice for the amount of 1,250.00 EUR. Payment is due by next Friday."

# TODO: Extract the amount and currency
amount = ""
currency = ""

rprint(f"Extracted Amount: {amount}")
rprint(f"Extracted Currency: {currency}")

# %% [markdown]
# ## 3. IR vs IE: The Conceptual Difference
#
# **Information Retrieval (IR)** is about finding *which* documents contain the information.
# **Information Extraction (IE)** is about finding *what* the specific information is within those documents.
#
# **Scenario:** You have a list of news snippets:
# 1. "Apple Inc. announced a new iPhone in Cupertino."
# 2. "The weather in Cupertino is sunny today."
# 3. "Microsoft is expanding its offices in Redmond."
#
# **Task:**
# 1. Implement a search that returns all snippets containing the word "Cupertino" (This is IR).
# 2. Implement a process that extracts the **Organization** mentioned in those snippets (This is IE).

# %%
snippets = [
    "Apple Inc. announced a new iPhone in Cupertino.",
    "The weather in Cupertino is sunny today.",
    "Microsoft is expanding its offices in Redmond."
]

query = "Cupertino"

# --- Part 1: IR ---
# TODO: Find all snippets that contain the query
retrieved_docs = []

# --- Part 2: IE ---
# TODO: For the retrieved docs, extract the Organization (use nlp from spaCy)
extracted_orgs = []

rprint(f"Retrieved Docs (IR): {retrieved_docs}")
rprint(f"Extracted Orgs (IE): {extracted_orgs}")
